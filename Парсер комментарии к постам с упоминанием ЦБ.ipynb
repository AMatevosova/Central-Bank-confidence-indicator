# %%
import requests
import pandas as pd
import time
import warnings
import re
warnings.filterwarnings('ignore')

# %%
token="здесь должен быть ваш токен"

# %%
group_name="aif_ru"
offset=0
count=100
all_posts=[]
all_comments=[]

# %% [markdown]
# # банк россии

# %%
offset=0
while offset<1700:
        req=requests.get('https://api.vk.com/method/wall.search',
               params={
                   'access_token': token,
                   'v': 5.131,
                   'domain': group_name,
                   'owners_only': 1,
                   'query': 'банк россии',
                   'count': count,
                   'offset': offset
                   
               })
        res=req.json()['response']['items']
        offset+=100
        time.sleep(1)
        all_posts.extend(res)

# %%
df = pd.json_normalize(all_posts)
df=df[["id", "owner_id", "date", "text", "comments.count"]]
df.rename(columns={'date': 'post_time','text':'post_text'}, inplace=True)
df['bool']=0
for i in range (len(df)):
    s=str(df.iloc[i]['post_text'])
    s=str(s)
    s=s.lower()
    c=bool(re.search(r'банк россии|банка россии|банку россии|банком россии|банке россии|цб|центробанк|центральный банк|центрального банка|центральному банку|центральным банком|центральном банке', s))
    df.loc[i,'bool']=df['bool'][i]+c
df=df[df['bool']==1]
df
# Out:
#           id  owner_id   post_time  \
# 3    2680528 -17862264  1708599146
# 4    2678707 -17862264  1708536301
# 5    2678327 -17862264  1708527000
# 6    2677451 -17862264  1708509300
# 10   2663820 -17862264  1708090203
# ..       ...       ...         ...
# 381  1650147 -17862264  1665918855
# 387  1611964 -17862264  1663867419
# 390  1608363 -17862264  1663695041
# 393  1601905 -17862264  1663333251
# 394  1601897 -17862264  1663332345
#
#                                              post_text  comments.count  bool
# 3    ✅ Отзыв лицензии у КИВИ Банка не освобождает з...               1     1
# 4    📱Что делать клиентам «КИВИ банка» и владельцам...              53     1
# 5    💬«Киви Банк появился в начале 2000-х годов в Р...               2     1
# 6    📊Банк России посоветовал россиянам, у которых ...               4     1
# 10   Дональд Трамп не раз публично заявлял, что смо...              32     1
# ..                                                 ...             ...   ...
# 381  Банк России обновляет купюру в 500 рублей. На ...              14     1
# 387  Центробанк России продолжает снижать ключевую ...               4     1
# 390  Центробанк России понизил ключевую ставку на 0...               3     1
# 393  По итогам 2022 года инфляция в РФ, согласно пр...               2     1
# 394  Центральный банк России шестой раз подряд сниз...               1     1
#
# [234 rows x 6 columns]

# %%
posts_id1=list(df[df['comments.count']!=0]['id'])

# %% [markdown]
# # цб

# %%
count=100
all_posts=[]
offset=0
while offset<1700:
        req=requests.get('https://api.vk.com/method/wall.search',
               params={
                   'access_token': token,
                   'v': 5.131,
                   'domain': group_name,
                   'owners_only': 1,
                   'query': 'цб',
                   'count': count,
                   'offset': offset
                   
               })
        res=req.json()['response']['items']
        offset+=100
        time.sleep(1)
        all_posts.extend(res)

# %%
df = pd.json_normalize(all_posts)
df=df[["id", "owner_id", "date", "text", "comments.count"]]
df.rename(columns={'date': 'post_time','text':'post_text'}, inplace=True)
df['bool']=0
for i in range (len(df)):
    s=str(df.iloc[i]['post_text'])
    s=str(s)
    s=s.lower()
    c=bool(re.search(r'банк россии|банка россии|банку россии|банком россии|банке россии|цб|центробанк|центральный банк|центрального банка|центральному банку|центральным банком|центральном банке', s))
    df.loc[i,'bool']=df['bool'][i]+c
df=df[df['bool']==1]
df
# Out:
#           id  owner_id   post_time  \
# 0    2679348 -17862264  1708564500
# 1    2678033 -17862264  1708520869
# 2    2677682 -17862264  1708513815
# 3    2677319 -17862264  1708506600
# 4    2677183 -17862264  1708503956
# ..       ...       ...         ...
# 575    25199 -17862264  1384930057
# 576    23694 -17862264  1383126120
# 577    16792 -17862264  1372070508
# 578    12844 -17862264  1363795930
# 579     2648 -17862264  1324040609
#
#                                              post_text  comments.count  bool
# 0    Что такое период охлаждения при выдаче кредито...               3     1
# 1    📢Заявления ЦБ о ситуации с Qiwi-банком:\n\n▫️Q...               4     1
# 2    💰Деньги россиян, «застрявшие» на Qiwi-кошелька...               8     1
# 3    💳Программа страхования вкладов не распространя...               0     1
# 4    👛 Вывод денег с Киви-кошельков стал невозможен...              19     1
# ..                                                 ...             ...   ...
# 575  С сегодняшнего дня ЦБ РФ отозвал лицензию у од...               0     1
# 576  Банк России выпустил памятные сторублевые банк...               5     1
# 577  23 июня  пост Сергея Игнатьева, возглавлявшего...               1     1
# 578  Вопрос дня № 7. Какие функции выполняет Центро...               3     1
# 579  Готовьтесь. Первый зампред ЦБ советует привыка...               4     1
#
# [522 rows x 6 columns]

# %%
posts_id2=list(df[df['comments.count']!=0]['id'])

# %% [markdown]
# # центробанк

# %%
count=100
all_posts=[]
offset=0
while offset<1700:
        req=requests.get('https://api.vk.com/method/wall.search',
               params={
                   'access_token': token,
                   'v': 5.131,
                   'domain': group_name,
                   'owners_only': 1,
                   'query': 'центробанк',
                   'count': count,
                   'offset': offset
                   
               })
        res=req.json()['response']['items']
        offset+=100
        time.sleep(1)
        all_posts.extend(res)

# %%
df = pd.json_normalize(all_posts)
df=df[["id", "owner_id", "date", "text", "comments.count"]]
df.rename(columns={'date': 'post_time','text':'post_text'}, inplace=True)
df['bool']=0
for i in range (len(df)):
    s=str(df.iloc[i]['post_text'])
    s=str(s)
    s=s.lower()
    c=bool(re.search(r'банк россии|банка россии|банку россии|банком россии|банке россии|цб|центробанк|центральный банк|центрального банка|центральному банку|центральным банком|центральном банке', s))
    df.loc[i,'bool']=df['bool'][i]+c
df=df[df['bool']==1]
df
# Out:
#           id  owner_id   post_time  \
# 0    2679348 -17862264  1708564500
# 1    2676869 -17862264  1708497901
# 2    2675454 -17862264  1708447060
# 3    2674799 -17862264  1708432953
# 4    2672707 -17862264  1708370101
# ..       ...       ...         ...
# 670    27337 -17862264  1386924762
# 671    25275 -17862264  1385018957
# 673    18306 -17862264  1374793555
# 674    17677 -17862264  1374053280
# 675    12844 -17862264  1363795930
#
#                                              post_text  comments.count  bool
# 0    Что такое период охлаждения при выдаче кредито...               3     1
# 1    Центробанк РФ отозвал лицензию у АО «КИВИ Банк...               0     1
# 2    💳 Как запретить оформление кредитов на свое им...              10     1
# 3    Институт Гайдара в январе провел свое ежегодно...              19     1
# 4    📈Центробанк подтвердил свое намерение держать ...               7     1
# ..                                                 ...             ...   ...
# 670  Вопрос дня № 3. Какие еще банки ЦБ лишил лицен...               0     1
# 671  Вопрос дня №2. Что делать, если вам нужно сроч...               0     1
# 673  Инфляция не выйдет за рамки официального прогн...               5     1
# 674  4 причины, почему России не грозит #дефолт: \n...               0     1
# 675  Вопрос дня № 7. Какие функции выполняет Центро...               3     1
#
# [578 rows x 6 columns]

# %%
posts_id3=list(df[df['comments.count']!=0]['id'])

# %% [markdown]
# # центральн банк

# %%
count=100
all_posts=[]
offset=0
while offset<1700:
        req=requests.get('https://api.vk.com/method/wall.search',
               params={
                   'access_token': token,
                   'v': 5.131,
                   'domain': group_name,
                   'owners_only': 1,
                   'query': 'центральн банк',
                   'count': count,
                   'offset': offset
                   
               })
        res=req.json()['response']['items']
        offset+=100
        time.sleep(1)
        all_posts.extend(res)

# %%
df = pd.json_normalize(all_posts)
df=df[["id", "owner_id", "date", "text", "comments.count"]]
df.rename(columns={'date': 'post_time','text':'post_text'}, inplace=True)
df['bool']=0
for i in range (len(df)):
    s=str(df.iloc[i]['post_text'])
    s=str(s)
    s=s.lower()
    c=bool(re.search(r'банк россии|банка россии|банку россии|банком россии|банке россии|цб|центробанк|центральный банк|центрального банка|центральному банку|центральным банком|центральном банке', s))
    df.loc[i,'bool']=df['bool'][i]+c
df=df[df['bool']==1]
df
# Out:
#           id  owner_id   post_time  \
# 0    2678916 -17862264  1708542902
# 1    2663820 -17862264  1708090203
# 2    2663106 -17862264  1708079521
# 3    2617466 -17862264  1706784420
# 6    2444339 -17862264  1701320911
# ..       ...       ...         ...
# 135   533687 -17862264  1461933204
# 136   490313 -17862264  1458366036
# 137   489186 -17862264  1458299195
# 138   416293 -17862264  1453450926
# 139   415342 -17862264  1453385580
#
#                                              post_text  comments.count  bool
# 0    5 вопросов про отзыв лицензии у КИВИ банка — ч...               1     1
# 1    Дональд Трамп не раз публично заявлял, что смо...              32     1
# 2    📊Центральный Банк РФ оставил ключевую ставку н...               5     1
# 3    📢С 1 февраля 2024 года российские банки обязан...               3     1
# 6    💬 «Например, вам предлагают купить чайник, но ...              14     1
# ..                                                 ...             ...   ...
# 135  Центральный Банк России сохранил ключевую став...              13     1
# 136  Согласно официальным данным Центробанка, в 201...              18     1
# 137  Центральный банк РФ принял решение сохранить к...              13     1
# 138  Цены на нефть растут  после заявлений главы Ев...              19     1
# 139  Европейский центральный банк оставил базовую с...              30     1
#
# [100 rows x 6 columns]

# %%
posts_id4=list(df[df['comments.count']!=0]['id'])

# %% [markdown]
# # Объединение списков

# %%
len(posts_id1+posts_id2+posts_id3+posts_id4)
# Out:
# 1330

# %%
posts_id=list(set(posts_id1+posts_id2+posts_id3+posts_id4))

# %%
len(posts_id)
# Out:
# 942

# %%
owner_id=-17862264

# %%
posts_id_part1=posts_id[:500]
posts_id_part2=posts_id[500:]

# %%
posts_id_part1=posts_id[:500]
posts_id_part2=posts_id[500:1000]
posts_id_part3=posts_id[1000:1500]
posts_id_part4=posts_id[1500:2000]
posts_id_part5=posts_id[2000:2500]
posts_id_part6=posts_id[2500:3200]
posts_id_part7=posts_id[3200:]

# %%
all_comments=[]

# %%
for post_id in posts_id_part1:
    req=requests.get('https://api.vk.com/method/wall.getComments',
               params={
                   'access_token': token,
                   'v': 5.131,
                   'owner_id': owner_id,
                   'post_id': post_id,
                   'count': 100
               })
    time.sleep(1)
    res=req.json()['response']['items']
    all_comments.extend(res)

# %%
data1 = pd.json_normalize(all_comments)
data1=data1[["post_id", "text", "date", "from_id"]]
data1.rename(columns={'date': 'comment_time', 'id': 'comment_id'}, inplace=True)
data1=data1.dropna()
data1['post_id'] = data1['post_id'].astype(int)
data1
# Out:
#       post_id                                               text  \
# 0     1148930  ЦБ не государственный ! По этому и живём в нищ...
# 1     1148930  А если заканчивается действие карты 30 июня? Т...
# 2     1409029                  Вот я дурень старый Уазик продал!
# 3     1409029                    Почему не делать аналоги самим?
# 4     1409029  А с какой это стати прямой импорт из Китая пер...
# ...       ...                                                ...
# 4190  2008169  а как быть с алмазным рудником -который угроби...
# 4191  2008169  Цифровой рубль нужен для на сокращения доли на...
# 4192  2008169  Опять водкой рассчитываться будем, как в 90е. ...
# 4193  2008169                        Чиновники себе яму роют 😂😂😂
# 4194  2008169
#
#       comment_time    from_id
# 0       1587720062  564715902
# 1       1587724523  132854477
# 2       1649912634  269778992
# 3       1649912734  198909762
# 4       1649913632   50852415
# ...            ...        ...
# 4190    1681974805  404728269
# 4191    1681999486  617546750
# 4192    1682090760  103774615
# 4193    1700255356    7612487
# 4194    1702847726  429974669
#
# [4145 rows x 4 columns]

# %%
all_comments=[]
for post_id in posts_id_part2:
    req=requests.get('https://api.vk.com/method/wall.getComments',
               params={
                   'access_token': token,
                   'v': 5.131,
                   'owner_id': owner_id,
                   'post_id': post_id,
                   'count': 100
               })
    time.sleep(1)
    res=req.json()['response']['items']
    all_comments.extend(res)
data2 = pd.json_normalize(all_comments)
data2=data2[["post_id", "text", "date", "from_id"]]
data2.rename(columns={'date': 'comment_time', 'id': 'comment_id'}, inplace=True)
data2=data2.dropna()
data2['post_id'] = data2['post_id'].astype(int)
data2
# Out:
#       post_id                                               text  \
# 0     2346090                                      Всё по плану.
# 1     2346090  Ниче не поняла, напиши простым русским языком ...
# 2     2346090  А какие эксплртеры? Можно список? Надеюсь это ...
# 3     2346090  Кто-то тут хочет доллар по 6 рублей, мда. А ка...
# 4     2346090  Ну, вот, а то все раскукарекались, что РФ ниче...
# ...       ...                                                ...
# 3787  2527229  Северный Кавказ больше всего долгов за ЖКХ жду...
# 3788  2527229                 Цены на коммуналку зашкаливают....
# 3789  2527229  Правительство продлило решение об отмене начис...
# 3790  2527229       ох спасибочки!!!!! заживем теперь, блин!!!🤣🤣
# 3791  2527229  А штрафы за чуть тёплые трубы и нечищенные тро...
#
#       comment_time    from_id
# 0       1697095891  695971892
# 1       1697109068  781011709
# 2       1697111041  761709378
# 3       1697113427  808499479
# 4       1697113881  707476227
# ...            ...        ...
# 3787    1704015049  708600308
# 3788    1704016499  232563349
# 3789    1704024359  695352659
# 3790    1704025174  341473031
# 3791    1704025983  269916880
#
# [3737 rows x 4 columns]

# %%
all_comments=[]
for post_id in posts_id_part3:
    req=requests.get('https://api.vk.com/method/wall.getComments',
               params={
                   'access_token': token,
                   'v': 5.131,
                   'owner_id': owner_id,
                   'post_id': post_id,
                   'count': 100
               })
    time.sleep(1)
    res=req.json()['response']['items']
    all_comments.extend(res)
data3 = pd.json_normalize(all_comments)
data3=data3[["post_id", "text", "date", "from_id"]]
data3.rename(columns={'date': 'comment_time', 'id': 'comment_id'}, inplace=True)
data3=data3.dropna()
data3['post_id'] = data3['post_id'].astype(int)
data3
# Out:
#       post_id                                               text  \
# 0     2568043  какой рост Зп и доходов все после выборов и по...
# 1     2568043                      Темпы роста отрицательные!..)
# 2     4616044  Ну, не просто так вчера поднимались эти вопрос...
# 3     4616044  Всё конечно отлично… но категория до 23х обычн...
# 4     4616044  помимо важного аспекта связи с народом, прямая...
# ...       ...                                                ...
# 4315  4396741  Это как сказать\n Эти санкции\n И операции\n И...
# 4316  4396741  Их в загон загнали и там они пока и будут нахо...
# 4317  4396741  [id810920979|Арсений], вы хотите аргументирова...
# 4318  2594503
# 4319  2594503                               кто бы сомневался...
#
#       comment_time    from_id
# 0       1634541278  479926974
# 1       1634545831   34533533
# 2       1702621847  801568038
# 3       1702626424  315311499
# 4       1702645931  793585052
# ...            ...        ...
# 4315    1694832613  737593749
# 4316    1694843366  115888101
# 4317    1694853844  460892336
# 4318    1636534337  349269962
# 4319    1636549873  184057622
#
# [4123 rows x 4 columns]

# %%
all_comments=[]
for post_id in posts_id_part4:
    req=requests.get('https://api.vk.com/method/wall.getComments',
               params={
                   'access_token': token,
                   'v': 5.131,
                   'owner_id': owner_id,
                   'post_id': post_id,
                   'count': 100
               })
    time.sleep(1)
    res=req.json()['response']['items']
    all_comments.extend(res)
data4 = pd.json_normalize(all_comments)
data4=data4[["post_id", "text", "date", "from_id"]]
data4.rename(columns={'date': 'comment_time', 'id': 'comment_id'}, inplace=True)
data4=data4.dropna()
data4['post_id'] = data4['post_id'].astype(int)
data4
# Out:
#       post_id                                               text  \
# 0     3569355  А вот  Не Понятно только : Зачем Россия с недр...
# 1     3569355
# 2     3569355         а что он за мировую экономику переживает??
# 3     3569355  Да даже без санкций запада, инфляция бы росла ...
# 4     3569355  Они уже осознали.\nТолько не могут. Хозяева не...
# ...       ...                                                ...
# 5128  4743165                               всех на пожизненное.
# 5129  4743165                           Танком раздавят? Сожгут?
# 5130  4743165                 Как можно было КАНАЛ организовать?
# 5131  4743165                             Было недавно,шо опять?
# 5132  4743165  От мэра Амстердама ещё не поступало предложени...
#
#       comment_time    from_id
# 0       1668591914  436193393
# 1       1668592202  330091606
# 2       1668592239  134066706
# 3       1668592293  756362994
# 4       1668592938  747028626
# ...            ...        ...
# 5128    1706872502  757977634
# 5129    1706873567  349269962
# 5130    1706876498  716207057
# 5131    1706885060  273178411
# 5132    1706935694  844443898
#
# [4922 rows x 4 columns]

# %%
all_comments=[]
for post_id in posts_id_part5:
    req=requests.get('https://api.vk.com/method/wall.getComments',
               params={
                   'access_token': token,
                   'v': 5.131,
                   'owner_id': owner_id,
                   'post_id': post_id,
                   'count': 100
               })
    time.sleep(1)
    res=req.json()['response']['items']
    all_comments.extend(res)
data5 = pd.json_normalize(all_comments)
data5=data5[["post_id", "text", "date", "from_id"]]
data5.rename(columns={'date': 'comment_time', 'id': 'comment_id'}, inplace=True)
data5=data5.dropna()
data5['post_id'] = data5['post_id'].astype(int)
data5
# Out:
#       post_id                                               text  \
# 0     1486853  Нам казахстанцам надо принять как можно больше...
# 1     1609734  Это даже очень хорошо. Спасибо правительству и...
# 2     1675272  Считаю, что давно пора уже начать очень активн...
# 3     1634313                                              О как
# 4     1634313  А че так?Продажи упали в Евросоюзе,без нас ни ...
# ...       ...                                                ...
# 1704   324695
# 1705   324695  [id45855670|Андрей], Цитата. Михаил Делягин Ро...
# 1706   324695  [id72929519|Ян], не знаю что там в официальных...
# 1707   324695  для этого и будут повышать пенсионный возраст ...
# 1708   324695  [id72929519|Ян], это же не Силу Янов живёт так...
#
#       comment_time    from_id
# 0       1686216707  593994234
# 1       1700045755  731071486
# 2       1707955587  244128822
# 3       1703310788  202587055
# 4       1703317957   24139614
# ...            ...        ...
# 1704    1522431537   45855670
# 1705    1522431822   72929519
# 1706    1522433213   45855670
# 1707    1522470487  450366077
# 1708    1522473847  253349726
#
# [1686 rows x 4 columns]

# %%
all_comments=[]
for post_id in posts_id_part6:
    req=requests.get('https://api.vk.com/method/wall.getComments',
               params={
                   'access_token': token,
                   'v': 5.131,
                   'owner_id': owner_id,
                   'post_id': post_id,
                   'count': 100
               })
    time.sleep(1)
    res=req.json()['response']['items']
    all_comments.extend(res)
data6 = pd.json_normalize(all_comments)
data6=data6[["post_id", "text", "date", "from_id"]]
data6.rename(columns={'date': 'comment_time', 'id': 'comment_id'}, inplace=True)
data6=data6.dropna()
data6['post_id'] = data6['post_id'].astype(int)
data6
# Out:
#       post_id                                               text  \
# 0     1676375  Повлияют! После выборов на всех забьют, как об...
# 1     1676375                                     Не уйдут гады!
# 2     1037401          Детям игрушки дарить и вкусняшки,радость!
# 3     1037401                                                  +
# 4     1037401  А работающие за минималку и так миллионеры, им...
# ...       ...                                                ...
# 2492  1579555
# 2493  1579555  И чо? Какие выводы? Кто виноват? Ручками ни в ...
# 2494  1579555          Рубль ушёл вниз,значит цены пойдут вверх.
# 2495  1579555      Думаю что после такого чутка цена вниз пойдёт
# 2496  1579555  Да мне кажется что там потом наладится все, по...
#
#       comment_time    from_id
# 0       1708107215   82062614
# 1       1708135886  846407409
# 2       1654011159   10412329
# 3       1654012403  115141378
# 4       1654012769  471806826
# ...            ...        ...
# 2492    1695827741  424531887
# 2493    1695830979   40643017
# 2494    1695831887  132031124
# 2495    1695833165  309814142
# 2496    1695851859  707243159
#
# [2472 rows x 4 columns]

# %%
all_comments=[]
for post_id in posts_id_part7:
    req=requests.get('https://api.vk.com/method/wall.getComments',
               params={
                   'access_token': token,
                   'v': 5.131,
                   'owner_id': owner_id,
                   'post_id': post_id,
                   'count': 100
               })
    time.sleep(1)
    res=req.json()['response']['items']
    all_comments.extend(res)
data7 = pd.json_normalize(all_comments)
data7=data7[["post_id", "text", "date", "from_id"]]
data7.rename(columns={'date': 'comment_time', 'id': 'comment_id'}, inplace=True)
data7=data7.dropna()
data7['post_id'] = data7['post_id'].astype(int)
data7
# Out:
#       post_id                                               text  \
# 0       47653                                Это маневр путина .
# 1       47653               [id183163335|Дима], многоходовочка..
# 2     1554984  24 года беспокойства о россиянах, рекорд досто...
# 3      391723                              Пора покупать доллар?
# 4      391723  Всем гасим долги! Куда то миллиарды уводятся! ...
# ...       ...                                                ...
# 2587  1507323  - главное, чтобы нам зарплату не стали выплачи...
# 2588  1507323          Только кордоб нам не хватает для счастья.
# 2589  1359869              Правильно! В наручники их и в тюрягу!
# 2590  1359869              Печальный опыт СССР он наверно забыл.
# 2591  1359869  в сша что ли демократия или в гейропе... не см...
#
#       comment_time    from_id
# 0       1417083997  183163335
# 1       1417086426  142024683
# 2       1692761979  694295529
# 3       1533194055  421743983
# 4       1533194459  162037943
# ...            ...        ...
# 2587    1688034507  247680196
# 2588    1688037069  429407576
# 2589    1676039199  548201888
# 2590    1676039868  173628274
# 2591    1676043237   24843729
#
# [2560 rows x 4 columns]

# %%
result=pd.concat([data1,data2,data3,data4,data5,data6,data7])

# %%
result=pd.concat([data1,data2])

# %%
result
# Out:
#       post_id                                               text  \
# 0     1148930  ЦБ не государственный ! По этому и живём в нищ...
# 1     1148930  А если заканчивается действие карты 30 июня? Т...
# 2     1409029                  Вот я дурень старый Уазик продал!
# 3     1409029                    Почему не делать аналоги самим?
# 4     1409029  А с какой это стати прямой импорт из Китая пер...
# ...       ...                                                ...
# 3787  2527229  Северный Кавказ больше всего долгов за ЖКХ жду...
# 3788  2527229                 Цены на коммуналку зашкаливают....
# 3789  2527229  Правительство продлило решение об отмене начис...
# 3790  2527229       ох спасибочки!!!!! заживем теперь, блин!!!🤣🤣
# 3791  2527229  А штрафы за чуть тёплые трубы и нечищенные тро...
#
#       comment_time    from_id
# 0       1587720062  564715902
# 1       1587724523  132854477
# 2       1649912634  269778992
# 3       1649912734  198909762
# 4       1649913632   50852415
# ...            ...        ...
# 3787    1704015049  708600308
# 3788    1704016499  232563349
# 3789    1704024359  695352659
# 3790    1704025174  341473031
# 3791    1704025983  269916880
#
# [7882 rows x 4 columns]

# %%
result.to_csv('aif_ru_comments_with_cb.csv', index=False)
