# %%
import requests
import pandas as pd
import time
import warnings
warnings.filterwarnings('ignore')

# %%
token="здесь должен быть ваш токен"

# %%
group_name="kommersant"
offset=0
count=100
all_posts=[]
all_comments=[]

# %% [markdown]
# # Инфляци

# %%
offset=0
while offset<1700:
        req=requests.get('https://api.vk.com/method/wall.search',
               params={
                   'access_token': token,
                   'v': 5.131,
                   'domain': group_name,
                   'owners_only': 1,
                   'query': 'инфляци',
                   'count': count,
                   'offset': offset
                   
               })
        res=req.json()['response']['items']
        offset+=100
        time.sleep(1)
        all_posts.extend(res)

# %%
df = pd.json_normalize(all_posts)
df=df[["id", "owner_id", "date", "text", "comments.count"]]
df.rename(columns={'date': 'post_time','text':'post_text'}, inplace=True)
df
# Out:
#           id  owner_id   post_time  \
# 0    3520863 -23482909  1708094395
# 1    3519857 -23482909  1708079772
# 2    3516173 -23482909  1707899485
# 3    3512720 -23482909  1707740441
# 4    3512162 -23482909  1707702602
# ..       ...       ...         ...
# 739  2136731 -23482909  1642017010
# 740  2136681 -23482909  1642011002
# 741  2136650 -23482909  1642008609
# 742  2135743 -23482909  1641865155
# 743  2135225 -23482909  1641779771
#
#                                              post_text  comments.count
# 0    Глава Центробанка Эльвира Набиуллина заявила, ...              49
# 1    ❗Банк России сохранил ключевую ставку на уровн...              14
# 2    На учете в Социальном фонде России (СФР) по со...              36
# 3    Владимир Путин заявил, что годовая инфляция в ...              28
# 4    Попытка снизить зависимость от иностранных пос...               0
# ..                                                 ...             ...
# 739  Курс доллара в мире обновил двухмесячный миним...               0
# 740  👨‍👩‍👦 Материнский капитал и другие соцвыплаты,...               2
# 741  Инфляция в России в декабре 2021 года ускорила...               4
# 742  Стоимость продовольствия в прошлом году в сред...              10
# 743  Инфляция в странах зоны евро в декабре продолж...               2
#
# [744 rows x 5 columns]

# %%
posts_id1=list(df[df['comments.count']!=0]['id'])

# %% [markdown]
# # Экономи

# %%
count=100
all_posts=[]
offset=0
while offset<1700:
        req=requests.get('https://api.vk.com/method/wall.search',
               params={
                   'access_token': token,
                   'v': 5.131,
                   'domain': group_name,
                   'owners_only': 1,
                   'query': 'экономи',
                   'count': count,
                   'offset': offset
                   
               })
        res=req.json()['response']['items']
        offset+=100
        time.sleep(1)
        all_posts.extend(res)

# %%
df = pd.json_normalize(all_posts)
df=df[["id", "owner_id", "date", "text", "comments.count"]]
df.rename(columns={'date': 'post_time','text':'post_text'}, inplace=True)
df
# Out:
#           id  owner_id   post_time  \
# 0    3507658 -23482909  1707440700
# 1    3505284 -23482909  1707373123
# 2    3502859 -23482909  1707271801
# 3    3487578 -23482909  1706601699
# 4    3484981 -23482909  1706484240
# ..       ...       ...         ...
# 542   130261 -23482909  1371110026
# 543    87369 -23482909  1355331169
# 544    82124 -23482909  1352972230
# 545    59862 -23482909  1345128342
# 546     2558 -23482909  1306323867
#
#                                              post_text  comments.count
# 0    Экспертная группа «Здравресурс» подсчитала, чт...               3
# 1    У украинской армии наблюдается серьезная нехва...              89
# 2    Как выяснил «Ъ», востребованность схемы с «дро...               1
# 3                                                                    0
# 4    В РФ растут розничные продажи накопителей и мо...               0
# ..                                                 ...             ...
# 542  "На телевидении не экономь!" - решили греки и ...               1
# 543                              "Я видел ад. Он тут".              25
# 544  Самая крупная за последние десятилетия акция п...              22
# 545  Плиточные накладки\n Страсти вокруг плитки в М...               2
# 546  На кухню, граждане!\nРезкое подорожание продук...               0
#
# [547 rows x 5 columns]

# %%
posts_id2=list(df[df['comments.count']!=0]['id'])

# %% [markdown]
# # Кредит

# %%
count=100
all_posts=[]
offset=0
while offset<1700:
        req=requests.get('https://api.vk.com/method/wall.search',
               params={
                   'access_token': token,
                   'v': 5.131,
                   'domain': group_name,
                   'owners_only': 1,
                   'query': 'кредит',
                   'count': count,
                   'offset': offset
                   
               })
        res=req.json()['response']['items']
        offset+=100
        time.sleep(1)
        all_posts.extend(res)

# %%
df = pd.json_normalize(all_posts)
df=df[["id", "owner_id", "date", "text", "comments.count"]]
df.rename(columns={'date': 'post_time','text':'post_text'}, inplace=True)
df
# Out:
#           id  owner_id   post_time  \
# 0    3521678 -23482909  1708105201
# 1    3521317 -23482909  1708100547
# 2    3519245 -23482909  1708038422
# 3    3519244 -23482909  1708038421
# 4    3519243 -23482909  1708038420
# ..       ...       ...         ...
# 724  2240064 -23482909  1647906129
# 725  2236725 -23482909  1647820749
# 726  2236700 -23482909  1647818347
# 727  2230499 -23482909  1647635587
# 728  2226743 -23482909  1647531045
#
#                                              post_text  comments.count
# 0    Совкомбанк и «Хоум банк» (бывший банк «Хоум Кр...               5
# 1    Как стало известно «Ъ», кассационный суд не со...               5
# 2    В США сейчас 43 млн жителей выплачивают студен...               1
# 3    Через три месяца у школьников начнутся выпускн...               1
# 4    Сбербанк MOEX: [SBER] обеспечивает более 98% в...               5
# ..                                                 ...             ...
# 724  Застройщики жилья, опасаясь падения продаж пос...               2
# 725  Половина работающих в России кэптивных банков ...               1
# 726  Рост ключевой ставки ЦБ до 20% привел к подоро...               8
# 727  Владелец российского ОТП-банка — венгерский OT...               3
# 728  Госпрограмму развития Крыма и Севастополя, сто...              12
#
# [729 rows x 5 columns]

# %%
posts_id3=list(df[df['comments.count']!=0]['id'])

# %% [markdown]
# # Валют

# %%
count=100
all_posts=[]
offset=0
while offset<1700:
        req=requests.get('https://api.vk.com/method/wall.search',
               params={
                   'access_token': token,
                   'v': 5.131,
                   'domain': group_name,
                   'owners_only': 1,
                   'query': 'валют',
                   'count': count,
                   'offset': offset
                   
               })
        res=req.json()['response']['items']
        offset+=100
        time.sleep(1)
        all_posts.extend(res)

# %%
df = pd.json_normalize(all_posts)
df=df[["id", "owner_id", "date", "text", "comments.count"]]
df.rename(columns={'date': 'post_time','text':'post_text'}, inplace=True)
df
# Out:
#           id  owner_id   post_time  \
# 0    3523837 -23482909  1708155240
# 1    3520997 -23482909  1708096288
# 2    3515755 -23482909  1707874981
# 3    3512188 -23482909  1707703802
# 4    3512001 -23482909  1707680160
# ..       ...       ...         ...
# 797  2292652 -23482909  1649352851
# 798  2290127 -23482909  1649276407
# 799  2289828 -23482909  1649271677
# 800  2289787 -23482909  1649271014
# 801  2285807 -23482909  1649155212
#
#                                              post_text  comments.count
# 0    Минувшую неделю доллар завершает существенным ...              11
# 1    Национальный банк Грузии смягчил требования дл...              10
# 2    В январе 2024 года продолжился приток капитала...               2
# 3    Отказ турецких банков от корреспондентских отн...              19
# 4    Косовские власти согласились отсрочить реализа...               1
# ..                                                 ...             ...
# 797  Китай начал оплачивать российский уголь в юаня...              69
# 798  Минфин перечислил в НРД рубли на выплаты купон...               4
# 799  Рубль продолжает уверенно укреплять позиции пр...              82
# 800  Министр финансов Джанет Йеллен выступила в ком...              20
# 801  Российский рубль хорошо противостоит санкциям ...              14
#
# [802 rows x 5 columns]

# %%
posts_id4=list(df[df['comments.count']!=0]['id'])

# %% [markdown]
# # Рубл

# %%
count=100
all_posts=[]
offset=0
while offset<1700:
        req=requests.get('https://api.vk.com/method/wall.search',
               params={
                   'access_token': token,
                   'v': 5.131,
                   'domain': group_name,
                   'owners_only': 1,
                   'query': 'рубл',
                   'count': count,
                   'offset': offset
                   
               })
        res=req.json()['response']['items']
        offset+=100
        time.sleep(1)
        all_posts.extend(res)

# %%
df = pd.json_normalize(all_posts)
df=df[["id", "owner_id", "date", "text", "comments.count"]]
df.rename(columns={'date': 'post_time','text':'post_text'}, inplace=True)
df
# Out:
#           id  owner_id   post_time  \
# 0    3523837 -23482909  1708155240
# 1    3516091 -23482909  1707896403
# 2    3515553 -23482909  1707859200
# 3    3512338 -23482909  1707722159
# 4    3512321 -23482909  1707719988
# ..       ...       ...         ...
# 488  3179326 -23482909  1689695400
# 489  3179027 -23482909  1689690600
# 490  3177968 -23482909  1689660208
# 491  3177814 -23482909  1689639180
# 492  3177811 -23482909  1689637980
#
#                                              post_text  comments.count
# 0    Минувшую неделю доллар завершает существенным ...              11
# 1    Перелома в борьбе с киберхищениями у клиентов ...               7
# 2    🔹 Президент России Владимир Путин, как ожидает...               3
# 3    Представители крупнейших банков отмечают, что ...               6
# 4    📰 Помощь Украине, Израилю и Тайваню прошла про...              59
# ..                                                 ...             ...
# 488  Координационный совет по вопросам обеспечения ...              32
# 489  Крупные производители напитков и соков PepsiCo...              25
# 490  Пресненский суд Москвы в рамках уголовного дел...               7
# 491  Удорожание импортных ингредиентов из-за падени...              10
# 492  Второй квартал заметно улучшил показатели част...               0
#
# [493 rows x 5 columns]

# %%
posts_id5=list(df[df['comments.count']!=0]['id'])

# %% [markdown]
# # Цен

# %%
count=100
all_posts=[]
offset=0
while offset<1700:
        req=requests.get('https://api.vk.com/method/wall.search',
               params={
                   'access_token': token,
                   'v': 5.131,
                   'domain': group_name,
                   'owners_only': 1,
                   'query': 'цен',
                   'count': count,
                   'offset': offset
                   
               })
        res=req.json()['response']['items']
        offset+=100
        time.sleep(1)
        all_posts.extend(res)

# %%
df = pd.json_normalize(all_posts)
df=df[["id", "owner_id", "date", "text", "comments.count"]]
df.rename(columns={'date': 'post_time','text':'post_text'}, inplace=True)
df
# Out:
#           id  owner_id   post_time  \
# 0    3519343 -23482909  1708057501
# 1    3519295 -23482909  1708049221
# 2    3519245 -23482909  1708038422
# 3    3519167 -23482909  1708027920
# 4    3517297 -23482909  1707940800
# ..       ...       ...         ...
# 556  3308580 -23482909  1696438404
# 557  3308509 -23482909  1696435183
# 558  3308227 -23482909  1696426594
# 559  3308075 -23482909  1696422582
# 560  3307675 -23482909  1696412287
#
#                                              post_text  comments.count
# 0    🔸 Минобороны РФ сообщило, что ночью были перех...               0
# 1    Как выяснил «Ъ», правительство решило поровну ...               2
# 2    В США сейчас 43 млн жителей выплачивают студен...               1
# 3    Российский экспорт нефти и нефтепродуктов в ян...               0
# 4    «Системный оператор» предлагает построить на Д...               9
# ..                                                 ...             ...
# 556  Средняя розничная цена дизельного топлива в Ро...              12
# 557  Общая сумма выплат нефтекомпаниям за сдерживан...               7
# 558  Ситуация на российском топливном рынке стабили...              18
# 559  Повышение налога на добавленную стоимость (НДС...              11
# 560  Европейская комиссия начала процедуру по защит...               6
#
# [561 rows x 5 columns]

# %%
posts_id6=list(df[df['comments.count']!=0]['id'])

# %% [markdown]
# # Ипоте

# %%
count=100
all_posts=[]
offset=0
while offset<1700:
        req=requests.get('https://api.vk.com/method/wall.search',
               params={
                   'access_token': token,
                   'v': 5.131,
                   'domain': group_name,
                   'owners_only': 1,
                   'query': 'ипоте',
                   'count': count,
                   'offset': offset
                   
               })
        res=req.json()['response']['items']
        offset+=100
        time.sleep(1)
        all_posts.extend(res)

# %%
df = pd.json_normalize(all_posts)
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Объединение списков

# %%
len(posts_id1+posts_id2+posts_id3+posts_id4+posts_id5+posts_id6)
# Out:
# 3116

# %%
posts_id=list(set(posts_id1+posts_id2+posts_id3+posts_id4+posts_id5+posts_id6))

# %%
len(posts_id)
# Out:
# 2753

# %%
owner_id=-23482909

# %%
posts_id_part1=posts_id[:500]
posts_id_part2=posts_id[500:1000]
posts_id_part3=posts_id[1000:1500]
posts_id_part4=posts_id[1500:2000]
posts_id_part5=posts_id[2000:2500]
posts_id_part6=posts_id[2500:]

# %%
all_comments=[]

# %%
for post_id in posts_id_part1:
    req=requests.get('https://api.vk.com/method/wall.getComments',
               params={
                   'access_token': token,
                   'v': 5.131,
                   'owner_id': owner_id,
                   'post_id': post_id,
                   'count': 100
               })
    time.sleep(1)
    res=req.json()['response']['items']
    all_comments.extend(res)

# %%
data1 = pd.json_normalize(all_comments)
data1=data1[["post_id", "text", "date", "from_id"]]
data1.rename(columns={'date': 'comment_time', 'id': 'comment_id'}, inplace=True)
data1=data1.dropna()
data1['post_id'] = data1['post_id'].astype(int)
data1
# Out:
#       post_id                                               text  \
# 0     3448834                Сколько на СВО ребятам  поделиться?
# 1     3448834                                     Выиграл финна?
# 2     3448834  Да пофигу, это теннис , у меня на него аллерги...
# 3     3448834                                     А обзор гольфа
# 4     2228229  Если 3000 компаний с числом сотрудников в них ...
# ...       ...                                                ...
# 3510  3310985  Интересно, ведь уведомление об этом будет посл...
# 3511  3310985  Только сейчас увидели? А в рекламе мелким текс...
# 3512  3310985  Путин с Набиулиной развели в стране ростовщиче...
# 3513  3310985                 Что то на малую сумму оштрафовали.
# 3514  3368329  Иногда собирание марок -может привести к неожи...
#
#       comment_time    from_id
# 0       1704626631  278307316
# 1       1704630487  711424050
# 2       1704638758  156062346
# 3       1704679523   15669009
# 4       1647599648   12025189
# ...            ...        ...
# 3510    1696589828   40948593
# 3511    1696589943  817574161
# 3512    1696597278  440255884
# 3513    1696656990  752521516
# 3514    1699972711  539613482
#
# [3294 rows x 4 columns]

# %%
all_comments=[]
for post_id in posts_id_part2:
    req=requests.get('https://api.vk.com/method/wall.getComments',
               params={
                   'access_token': token,
                   'v': 5.131,
                   'owner_id': owner_id,
                   'post_id': post_id,
                   'count': 100
               })
    time.sleep(1)
    res=req.json()['response']['items']
    all_comments.extend(res)
data2 = pd.json_normalize(all_comments)
data2=data2[["post_id", "text", "date", "from_id"]]
data2.rename(columns={'date': 'comment_time', 'id': 'comment_id'}, inplace=True)
data2=data2.dropna()
data2['post_id'] = data2['post_id'].astype(int)
data2
# Out:
#       post_id                                               text  \
# 0     3368331                               А как же "Спартак"?😮
# 1     3458447  Если Ормузский пролив перекроют, то вообще не ...
# 3     3425685                         Мало Россия долгов списала
# 4     3425685                         Яйцами пусть долги отдают!
# 5     3425685              Ну, кредитуйте Африку дальше, идиЁты.
# ...       ...                                                ...
# 3523  2837314  Когда хочется прогресса , любая чушь выдаётся ...
# 3524  2837314  Кредиты пусть сделают доступными для населения...
# 3525  2837314  Значит скоро государство к нам в карман залезет..
# 3526  2837314  Ага конечно ..население отложило себе на черны...
# 3527  2837314  Кто это такие -"домохозяйства",у которых всё т...
#
#       comment_time    from_id
# 0       1699990664  275404203
# 1       1705094268  741565741
# 3       1703305530  792093412
# 4       1703306855  212943413
# 5       1703315409    1302320
# ...            ...        ...
# 3523    1674191056  570359098
# 3524    1674202845  138697298
# 3525    1674207182  263061701
# 3526    1674208294   12025189
# 3527    1674210595    1888993
#
# [3297 rows x 4 columns]

# %%
all_comments=[]
for post_id in posts_id_part3:
    req=requests.get('https://api.vk.com/method/wall.getComments',
               params={
                   'access_token': token,
                   'v': 5.131,
                   'owner_id': owner_id,
                   'post_id': post_id,
                   'count': 100
               })
    time.sleep(1)
    res=req.json()['response']['items']
    all_comments.extend(res)
data3 = pd.json_normalize(all_comments)
data3=data3[["post_id", "text", "date", "from_id"]]
data3.rename(columns={'date': 'comment_time', 'id': 'comment_id'}, inplace=True)
data3=data3.dropna()
data3['post_id'] = data3['post_id'].astype(int)
data3
# Out:
#       post_id                                               text  \
# 0      379715                     Зачем одному дому две крыши...
# 1      379715  Рубрика "Настало время удивительных историй" с...
# 2      379715  Посредник это риэлтер. Кроме поиска недвижки, ...
# 3      379715  [id178559482|Михаил], ты прав во всем. Только ...
# 4      379715  с такой логикой можно и врачей и учителей выки...
# ...       ...                                                ...
# 3294  3240288  ‼«У нас сегодня заблокированы активы более 3,5...
# 3295  3240288
# 3296  3240288                      Свои бабки будут отбивать )))
# 3297  2724197                                             Смишно
# 3298  2724197  Как не было абсурдно ..а такой низкий курс бье...
#
#       comment_time    from_id
# 0       1421075930   82947803
# 1       1421076005    1761075
# 2       1421076260  178559482
# 3       1421076409   72177677
# 4       1421076469  173781148
# ...            ...        ...
# 3294    1692737851  642256661
# 3295    1692759684   62429361
# 3296    1692760313   72356250
# 3297    1668815596  187163445
# 3298    1668847383   12025189
#
# [3059 rows x 4 columns]

# %%
all_comments=[]
for post_id in posts_id_part4:
    req=requests.get('https://api.vk.com/method/wall.getComments',
               params={
                   'access_token': token,
                   'v': 5.131,
                   'owner_id': owner_id,
                   'post_id': post_id,
                   'count': 100
               })
    time.sleep(1)
    res=req.json()['response']['items']
    all_comments.extend(res)
data4 = pd.json_normalize(all_comments)
data4=data4[["post_id", "text", "date", "from_id"]]
data4.rename(columns={'date': 'comment_time', 'id': 'comment_id'}, inplace=True)
data4=data4.dropna()
data4['post_id'] = data4['post_id'].astype(int)
data4
# Out:
#       post_id                                               text  \
# 0     3289450                                   0n00. Mjdxk 3 ve
# 2     3150187            Типа, "а в попугаях я все таки длиннее"
# 3     3150187  Мировые экономики сошлись на территории Украин...
# 4     3150187  Ну тык, ничего нового. Я об этом еще говорил н...
# 6     3150187  Все в частных руках и впервую очередь карманы ...
# ...       ...                                                ...
# 3450  2365218                Это учтено укрепление после обвала?
# 3451  2365218  Нестыковочка. Почему тогда эту валюту не покуп...
# 3452  2365218  Рубль - теперь не свободно-конвертируемая валю...
# 3453  2365218  Полная брехня, рубль всё ещё частная валюта то...
# 3454  2365218  Ещё б, как с Азербайджаном торговать как можно...
#
#       comment_time    from_id
# 0       1695327139  293818534
# 2       1688227550    1208056
# 3       1688227605  510425105
# 4       1688227701    6829186
# 6       1688227922  329433180
# ...            ...        ...
# 3450    1652366858  100511355
# 3451    1652368980  711424050
# 3452    1652417442   49582408
# 3453    1652439189  510278539
# 3454    1652441749  691094272
#
# [3188 rows x 4 columns]

# %%
all_comments=[]
for post_id in posts_id_part5:
    req=requests.get('https://api.vk.com/method/wall.getComments',
               params={
                   'access_token': token,
                   'v': 5.131,
                   'owner_id': owner_id,
                   'post_id': post_id,
                   'count': 100
               })
    time.sleep(1)
    res=req.json()['response']['items']
    all_comments.extend(res)
data5 = pd.json_normalize(all_comments)
data5=data5[["post_id", "text", "date", "from_id"]]
data5.rename(columns={'date': 'comment_time', 'id': 'comment_id'}, inplace=True)
data5=data5.dropna()
data5['post_id'] = data5['post_id'].astype(int)
data5
# Out:
#       post_id                                               text  \
# 0     3512099                                                ...
# 1     3512099  Кубань - житница России.\nНо что происходит с ...
# 2     3364646  Глава думского комитета по финансовым рынкам А...
# 3     3364646  Плевать на курс,честно говоря,ибо получаю в ру...
# 4     3364646  Завтра негр в африке чихнет,рубль упадет,унас ...
# ...       ...                                                ...
# 3638  3226912                                   Росстат наше всё
# 3639  3226912               Бред.\n\nЧерти кто черти что считает
# 3640  3226912  Остальные 90%, как понимаю, нашему правительст...
# 3641  3226912
# 3642  3226912  На сотку не просто прожить. Ну если только одн...
#
#       comment_time    from_id
# 0       1707712397  194894013
# 1       1707718466  713436686
# 2       1699758294  588717367
# 3       1699773346  800977489
# 4       1699806753  329433180
# ...            ...        ...
# 3638    1692017544  420447217
# 3639    1692018744  748385129
# 3640    1692020722  196492674
# 3641    1692030572   33490926
# 3642    1692131791   64366271
#
# [3380 rows x 4 columns]

# %%
all_comments=[]
for post_id in posts_id_part6:
    req=requests.get('https://api.vk.com/method/wall.getComments',
               params={
                   'access_token': token,
                   'v': 5.131,
                   'owner_id': owner_id,
                   'post_id': post_id,
                   'count': 100
               })
    time.sleep(1)
    res=req.json()['response']['items']
    all_comments.extend(res)
data6 = pd.json_normalize(all_comments)
data6=data6[["post_id", "text", "date", "from_id"]]
data6.rename(columns={'date': 'comment_time', 'id': 'comment_id'}, inplace=True)
data6=data6.dropna()
data6['post_id'] = data6['post_id'].astype(int)
data6
# Out:
#       post_id                                               text  \
# 0     2317607  Если это произойдет, это прям будет подарок су...
# 1     2317607                            "...о великая пустота!"
# 2     3415338   А зарплату для первого взноса не подняли вообще.
# 3     2243883                                    А чем отдавать?
# 4     2243883  "Кто берёт в кредит, сам себе вредит', - Так г...
# ...       ...                                                ...
# 1793  3375096                                                 👏👍
# 1794  3375096       Ещё один шоумен. Жди беды, страна Аргентина.
# 1795  3375096                                              Элвис
# 1796  3375096               А глаза пустые как у моего водителя!
# 1797  1867774  "Бюджетная поддержка проектов энергоэффективно...
#
#       comment_time    from_id
# 0       1650276295   61340431
# 1       1650279544  391941134
# 2       1702709540   93625577
# 3       1648004914  713405098
# 4       1648025773  596477168
# ...            ...        ...
# 1793    1700489472  417875434
# 1794    1700502879  829984708
# 1795    1700511011  545592400
# 1796    1700515559  478581902
# 1797    1610968081    3233437
#
# [1700 rows x 4 columns]

# %%
result=pd.concat([data1,data2,data3,data4,data5,data6])

# %%
result
# Out:
#       post_id                                               text  \
# 0     3448834                Сколько на СВО ребятам  поделиться?
# 1     3448834                                     Выиграл финна?
# 2     3448834  Да пофигу, это теннис , у меня на него аллерги...
# 3     3448834                                     А обзор гольфа
# 4     2228229  Если 3000 компаний с числом сотрудников в них ...
# ...       ...                                                ...
# 1793  3375096                                                 👏👍
# 1794  3375096       Ещё один шоумен. Жди беды, страна Аргентина.
# 1795  3375096                                              Элвис
# 1796  3375096               А глаза пустые как у моего водителя!
# 1797  1867774  "Бюджетная поддержка проектов энергоэффективно...
#
#       comment_time    from_id
# 0       1704626631  278307316
# 1       1704630487  711424050
# 2       1704638758  156062346
# 3       1704679523   15669009
# 4       1647599648   12025189
# ...            ...        ...
# 1793    1700489472  417875434
# 1794    1700502879  829984708
# 1795    1700511011  545592400
# 1796    1700515559  478581902
# 1797    1610968081    3233437
#
# [17918 rows x 4 columns]

# %%
result.to_csv('kommersant_all_comments.csv', index=False)
